# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 6, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y1 = np.sin(x)
y2 = np.cos(x)

# draw

plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle="--", label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title("sin & cos")
plt.legend()
plt.show()

# %%
from matplotlib.image import imread

img = imread("스크린샷 2026-03-12 155744.png")

plt.imshow(img)
plt.show()
